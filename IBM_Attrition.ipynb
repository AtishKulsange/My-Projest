# %% [markdown]
# # IBM HR Analytics Employee Attrition & Performance
#
# ## Introduction
#
# This is a fictional data set created by IBM data scientists. Uncover the factors that lead to employee attrition and predict attrition of your valuable employees.
#
# So what is Attrition and what determines it?
#
#
# **Attrition:** It is basically the turnover rate of employees inside an organization.In the realm of human resources, attrition is defined as both the voluntary and involuntary reduction of a company’s workforce through deaths, employee retirements, transfers, resignations and terminations.
#
# **This can happen for many reasons:**
# - Employees looking for better opportunities.
# - A negative working environment.
# - Bad management
# - Sickness of an employee (or even death)
# - Excessive working hours
#
# Employees are the backbone of the organization. Organization's performance is heavily based on the quality of the employees. Challenges that an organization has to face due employee attrition are:
# - Expensive in terms of both money and time to train new employees.
# - Loss of experienced employees
# - Impact in productivity
# - Impact profit
#
# ## Objective
#
# Predicting if a particular employee is going to leave the organization?
#
# Attrition has always been a major concern in any organization. The time, money and effort invested in training new employees, the work dependency and other factors leads to a massive overall loss to the firm when an employee leaves. Also, attrition causes distrust among existing employees which can itself become a major difficulty for the management of the organization.
#
# The IBM HR Attrition Case Study is a fictional dataset which aims to identify important factors that might be influential in determining which employee might leave the firm and who may not. This article provides in-depth analysis as well as predictive modelling to understand important factors and make accurate predictions.
#
# ### Table of Content
#
# - Data Preparation and Understanding.
# - Feature Selection.
# - Model Fitting
# - Model Comparison
# - Recommendations & Conclusion.

# %% [markdown]
# ## Data Preparation and Understanding.
# ### Importing libraries

# %%
# importing libraries to import dataset and perform statestical opration
import numpy as np
import pandas as pd

# %% [markdown]
# ### importing dataset in datafrem and showing first 5 rows

# %%
#reading dataset in csv format and displaying first 5 rows
df=pd.read_csv('Employee-Attrition.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %% [markdown]
# ## Showing shape of dataframe

# %%
#shape of dataset
df.shape
# Out:
# (1470, 35)

# %% [markdown]
# ## dataset information
#
# This dataset contains:1470 observations (rows) and 35 features (variables). Variable “Attrition” is the label in our dataset and we would like to build a Machine Learning Model to predictthe attrition of employee i.e., employee leaving the organization!
#
# ### columns information
#
# - Age:- this column shows the age of the employee
# - Attrition:- it gives which employee is reduction of a company’s workforce
# - BusinessTravel:- employee's frequency travels  for business or not
# - DailyRate:- daly payment rate of employee
# - Department:- employees department
# - DistanceFromHome:- employees distance travels daily from home to office
# - Education:- recent education of employee in numbers
# - EducationField:- employees education field
# - EmployeeCount:- count of employee in row wise
# - EmployeeNumber:- number of employee in that row field
# - EnvironmentSatisfaction:- how much employee is satisfied in company environment
# - Gender:- gender of employee whether male of female
# - HourlyRate:- hourly rate of employee which paid to employee
# - JobInvolvement:- how much employee envolve in there job
# - JobLevel:- the lavel of employees profile
# - JobRole:- job position
# - JobSatisfaction:- job satisfaction in company of employee
# - MaritalStatus:- marital status of employee
# - MonthlyIncome:- monthaly income of employee
# - MonthlyRate:- monthaly rate of employee
# - NumCompaniesWorked:- in how many company did a employee worked priviously
# - Over18:- is employee over 18 year age or not
# - OverTime:- is employee works overtime
# - PercentSalaryHike:- percent of incriment given to employee compair to privious
# - PerformanceRating:-the ratings of employee acording to there performance
# - RelationshipSatisfaction:- satisfaction of employee to company
# - StandardHours:- standerd hour of working in company for each employee
# - StockOptionLevel:- raiting of stock option lavel in company
# - TotalWorkingYears:- total year does employee work
# - TrainingTimesLastYear:- How many months did employee get training in company last year
# - WorkLifeBalance:- rating for balanced in life and work
# - YearsAtCompany:- from how many year the employee work in current company
# - YearsInCurrentRole:- from how many year does employee work in same profile
# - YearsSinceLastPromotion:- years of geting last promotion to today
# - YearsWithCurrManager:- years of working under same manager

# %% [markdown]
# ### dataset have 35 attributes and 1470 rows

# %%
# information about all columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# ### there is no any missing value and no Nan values in the data set some are intiger columans and some are object type columns

# %%
#finding total number of null values column wise
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
#basic statestical operation on data set like mean standerd deviation quartiles and min max
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# - some columan have single value like EmployeeCount, Standerd hour
# - the statestical oparation like count, mean, standerd daviation, 25% quartile, 50% Quartile, 75% quartile and minimum and maximum are given in above table

# %%
# displaying total values of categories in target variable
df['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
# importing libraries for visualisation
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# shoing count plot on Attrition
sns.countplot(x='Attrition',data=df)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %% [markdown]
# The above graph shows the distribution of the target variable. Out of the total of 1470 observations, 1233 is No whereas 167 is Yes. We will treat this imbalance after splitting the data into Training and Test Set.
#
# The dataset has no missing values. Hence, no further treatment is required pertaining to the missing values. Let us use box plot to observe the outliers.

# %%
for col in df.columns:
    if df[col].dtype!= object:
        print(str(col+' : '+str(df[col].unique())))
        print(df[col].value_counts())
        print('__________________________________________________')
# Out:
# Age : [41 49 37 33 27 32 59 30 38 36 35 29 31 34 28 22 53 24 21 42 44 46 39 43
#  50 26 48 55 45 56 23 51 40 54 58 20 25 19 57 52 47 18 60]
# 35    78
# 34    77
# 36    69
# 31    69
# 29    68
# 32    61
# 30    60
# 33    58
# 38    58
# 40    57
# 37    50
# 27    48
# 28    48
# 42    46
# 39    42
# 45    41
# 41    40
# 26    39
# 44    33
# 46    33
# 43    32
# 50    30
# 25    26
# 24    26
# 49    24
# 47    24
# 55    22
# 51    19
# 53    19
# 48    19
# 54    18
# 52    18
# 22    16
# 56    14
# 23    14
# 58    14
# 21    13
# 20    11
# 59    10
# 19     9
# 18     8
# 60     5
# 57     4
# Name: Age, dtype: int64
# __________________________________________________
# DailyRate : [1102  279 1373 1392  591 1005 1324 1358  216 1299  809  153  670 1346
#   103 1389  334 1123 1219  371  673 1218  419  391  699 1282 1125  691
#   477  705  924 1459  125  895  813 1273  869  890  852 1141  464 1240
#  1357  994  721 1360 1065  408 1211 1229  626 1434 1488 1097 1443  515
# ...

# %%
print('all insights of columns')
for col in df.columns:
    if df[col].dtype== object:
        print(str(col+' : '+str(df[col].unique())))
        print(df[col].value_counts())
        print('__________________________________________________')
# Out:
# all insights of columns
# Attrition : ['Yes' 'No']
# No     1233
# Yes     237
# Name: Attrition, dtype: int64
# __________________________________________________
# BusinessTravel : ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64
# __________________________________________________
# Department : ['Sales' 'Research & Development' 'Human Resources']
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64
# __________________________________________________
# EducationField : ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64
# ...

# %%
colm=[]
for col in df.columns:
    if col!='MonthlyRate' and col!='MonthlyIncome' and col!='DailyRate':
        colm.append(col)
plt.subplots(figsize=(40,7))       
sns.boxplot(data=df[colm])
# Out:
# <AxesSubplot:>

# %% [markdown]
# Age, DailyRate, DistanceFromHome, HourlyRate, MonthlyRate, PercentSalaryHike tend not to have any outliers.
#
# NumCompaniesWorked, TrainingTimesLastYear, YearsWithCurrManager, YearsInCurrentRole have a moderate number of outliers.
#
# MonthlyIncome, TotalWorkingYears, YearsAtCompany, YearsSinceLastPromotion have large number of outliers.
#
# One way to counter this problem is by scaling the variables so as to reduce its effect on the model. The StandardScaler() in Python’s Scikit-learn library can be used for this purpose.
#
# One final step before moving further is to check for multi collinearity. We plot a correlation matrix for this purpose.

# %%
# calculating corilation between columns
df.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %%
# visuslising corilation using heatmap
plt.subplots(figsize=(20,20))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %% [markdown]
# The above graph shows the correlation between independent variables. We perform this to necessarily check for multi collinearity. A rule of thumb that is followed for multi collinearity is if correlation coefficient (r) is close to 0.80. Based on that we identify the following variables to have a high correlation:
#
# Correlation between MonthlyIncome and JobLevel is 0.95. This is a very high correlation.
#
# Correlation between TotalWorkingYears and JobLevel is 0.78 which is also very close to 0.80.
#
# All other variables seem to have a correlation which is less than 0.80.
#
# Having got an understanding of the data along with preliminary analysis, we can now more onto Feature Engineering.

# %% [markdown]
# # visualization
#
# visualization of columns vs attrition column

# %%
# displaying plot for all numeric columns
fig,ax = plt.subplots(8,3, figsize=(9,9))                
sns.histplot(df['Age'], ax = ax[0,0]) 
sns.histplot(df['DailyRate'], ax = ax[0,1]) 
sns.histplot(df['DistanceFromHome'], ax = ax[0,2]) 
sns.histplot(df['Education'], ax = ax[1,0]) 
sns.histplot(df['EnvironmentSatisfaction'], ax = ax[1,1]) 
sns.histplot(df['HourlyRate'], ax = ax[1,2]) 
sns.histplot(df['JobInvolvement'], ax = ax[2,0]) 
sns.histplot(df['JobLevel'], ax = ax[2,1]) 
sns.histplot(df['JobSatisfaction'], ax = ax[2,2]) 
sns.histplot(df['MonthlyIncome'], ax = ax[3,0])

sns.histplot(df['MonthlyRate'], ax = ax[3,1])
sns.histplot(df['NumCompaniesWorked'], ax = ax[3,2])
sns.histplot(df['PercentSalaryHike'], ax = ax[4,0])
sns.histplot(df['PerformanceRating'], ax = ax[4,1])
sns.histplot(df['RelationshipSatisfaction'], ax = ax[4,2])
sns.histplot(df['WorkLifeBalance'], ax = ax[5,0])
sns.histplot(df['YearsAtCompany'], ax = ax[5,1])  
sns.histplot(df['YearsInCurrentRole'], ax = ax[5,2])
sns.histplot(df['YearsSinceLastPromotion'], ax = ax[6,0])
sns.histplot(df['YearsWithCurrManager'], ax = ax[6,1])
sns.histplot(df['StockOptionLevel'], ax = ax[6,2]) 
sns.histplot(df['TotalWorkingYears'], ax = ax[7,0])
sns.histplot(df['TrainingTimesLastYear'], ax = ax[7,1])


plt.tight_layout()
plt.show()

# %% [markdown]
# from above plots the observations are:
# - Age, DailyRate, DistanceFromHome, HourlyRate, MonthalyIncome, MonthlyRate, NumComponyWorked, PercentSalaryHike, YearAtCompany, YearInCurrentRole, YearSinceLastPromotion, YearWithCurrRole, TotalWorkingYears, YearWithCurrManager columns are continous numeric values
# - Education, EnvironmentSatisfaction, JobSatisfaction, JobEnvironment, JobLevel, performanceRating, RelationshipSatisfaction, WorkLifeBalance, StockOptionLevel columns are numerical Categories values

# %%
plt.subplots(figsize=(16,7))
sns.countplot(x='Age', hue="Attrition", data=df,palette='colorblind')
plt.show()

# %% [markdown]
# #### Whose age is between 18 to 37 are most attrite

# %%
plt.subplots(figsize=(16,7))
sns.countplot(x='BusinessTravel', hue="Attrition", data=df,palette='colorblind')
plt.show()

# %%
plt.subplots(figsize=(16,7))
sns.countplot(x='Department', hue="Attrition", data=df,palette='colorblind')
plt.show()

# %%
plt.subplots(figsize=(16,7))
sns.countplot(x='Education', hue="Attrition", data=df,palette='colorblind')
plt.show()

# %%
plt.subplots(figsize=(16,7))
sns.countplot(x='EducationField', hue="Attrition", data=df,palette='colorblind')
plt.show()

# %%
plt.subplots(figsize=(16,7))
sns.countplot(x='EnvironmentSatisfaction', hue="Attrition", data=df,palette='colorblind')
plt.show()

# %%
plt.subplots(figsize=(16,7))
sns.countplot(x='Gender', hue="Attrition", data=df,palette='colorblind')
plt.show()

# %%
plt.subplots(figsize=(20,7))
sns.countplot(x='JobInvolvement', hue="Attrition", data=df,palette='colorblind')
plt.show()

# %%
plt.subplots(figsize=(20,7))
sns.countplot(x='JobLevel', hue="Attrition", data=df,palette='colorblind')
plt.show()

# %%
plt.subplots(figsize=(20,7))
sns.countplot(x='JobRole', hue="Attrition", data=df,palette='colorblind')
plt.show()

# %%
plt.subplots(figsize=(20,7))
sns.countplot(x='JobSatisfaction', hue="Attrition", data=df,palette='colorblind')
plt.show()

# %%
plt.subplots(figsize=(20,7))
sns.countplot(x='MaritalStatus', hue="Attrition", data=df,palette='colorblind')
plt.show()

# %%
plt.subplots(figsize=(20,7))
sns.countplot(x='NumCompaniesWorked', hue="Attrition", data=df,palette='colorblind')
plt.show()

# %%
plt.subplots(figsize=(20,7))
sns.countplot(x='OverTime', hue="Attrition", data=df,palette='colorblind')
plt.show()

# %%
plt.subplots(figsize=(20,7))
sns.countplot(x='PercentSalaryHike', hue="Attrition", data=df,palette='colorblind')
plt.show()

# %%
plt.subplots(figsize=(20,7))
sns.countplot(x='PerformanceRating', hue="Attrition", data=df,palette='colorblind')
plt.show()

# %%
plt.subplots(figsize=(20,7))
sns.countplot(x='RelationshipSatisfaction', hue="Attrition", data=df,palette='colorblind')
plt.show()

# %%
plt.subplots(figsize=(20,7))
sns.countplot(x='StockOptionLevel', hue="Attrition", data=df,palette='colorblind')
plt.show()

# %%
plt.subplots(figsize=(20,7))
sns.countplot(x='TotalWorkingYears', hue="Attrition", data=df,palette='colorblind')
plt.show()

# %%
plt.subplots(figsize=(20,7))
sns.countplot(x='TrainingTimesLastYear', hue="Attrition", data=df,palette='colorblind')
plt.show()

# %%
plt.subplots(figsize=(20,7))
sns.countplot(x='WorkLifeBalance', hue="Attrition", data=df,palette='colorblind')
plt.show()

# %%
plt.subplots(figsize=(20,7))
sns.countplot(x='YearsAtCompany', hue="Attrition", data=df,palette='colorblind')
plt.show()

# %%
plt.subplots(figsize=(20,7))
sns.countplot(x='YearsInCurrentRole', hue="Attrition", data=df,palette='colorblind')
plt.show()

# %%
plt.subplots(figsize=(20,7))
sns.countplot(x='YearsSinceLastPromotion', hue="Attrition", data=df,palette='colorblind')
plt.show()

# %%
plt.subplots(figsize=(20,7))
sns.countplot(x='YearsWithCurrManager', hue="Attrition", data=df,palette='colorblind')
plt.show()

# %% [markdown]
# in above plot we know that the the the employee whose work with same manager working from 0,2 3 7 year are attrite megerly

# %% [markdown]
# by observing corilation matrix the data is not so corilate with each other

# %% [markdown]
# ## Feature Selection
# Based on the Exploratory Data Analysis and Descriptive Statistical Analysis, we select and deselect certain variables which do not significant contribute to our model. The variables are deselected based on the following:
#
# Variable type
# Invariability in the Data point
# Independence between Target variable and Independent variable
# Multicollinearity
# Variable Type:
#
# The nominal variable is not used in the analysis as it does not provide any input to the model building process. It is however kept so as to identify the employees on whom the study is done.
#
# Invariability in the Data point:
#
# Certain variables do not have any variability in them. Such variables are:
#
# Employee Count: This is just a count of employee and the value it takes is always 1.
# Over18: This variable describes if an employee is over 18 years of age. It takes the value ‘Yes’ in all cases.
# StandardHours: The standard number of hours an employee works in a week.
#
# Its constant value is 80

# %%
# droping the columns
df=df.drop('Over18', axis=1)
df=df.drop('EmployeeNumber', axis=1)
df=df.drop('StandardHours', axis=1)
df=df.drop('EmployeeCount', axis=1)

# %% [markdown]
# # Model Fitting

# %%
from sklearn.model_selection import train_test_split

# to obtain the mutual information values
from sklearn.feature_selection import mutual_info_classif
# to select the features
from sklearn.feature_selection import SelectKBest

# %% [markdown]
# ### Preprocessing of data

# %%
df["Age_year"]=df["Age"]

# %%
df=df.drop("Age", axis=1)

# %% [markdown]
# ### applyning label encoding to attrition and overtime columns

# %%
# converting categorical values to numerical using Label encoding
from sklearn.preprocessing import LabelEncoder

df['Attrition']=LabelEncoder().fit_transform(df['Attrition'])
df['OverTime']=LabelEncoder().fit_transform(df['OverTime'])

# %% [markdown]
# ### applying One Hot Encoding to reamaining all categorical data

# %%
# converting categorical data into dummy variable by using One Hot Encoding
list1=list()
for col in df.columns:
    if df[col].dtype==object and col!='Attrition' and col!='OverTime':
        # Get one hot encoding of columns B
        one_hot = pd.get_dummies(df[col])
        #one_hot=one_hot.drop(one_hot[0],axis='columns')
        list1.append(one_hot.columns)
        # Drop column B as it is now encoded
        df = df.drop(col,axis = 1)
        # Join the encoded df
        df = pd.concat([df,one_hot],axis='columns')

# %% [markdown]
# ### For avoiding Dammy Variable Trap by creating corilation between columns we have to delete one one columan from each of categorical value

# %%
df=df.drop('Non-Travel',axis='columns')
df=df.drop('Human Resources',axis='columns')
df=df.drop('Female',axis='columns')
df=df.drop('Healthcare Representative',axis='columns')
df=df.drop('Divorced',axis='columns')

# %% [markdown]
# ### splitting data into X and Y
#
# After pre-processing, we split our data into training, validation and test dataset. From a total of 1470 observations, we choose:
#
# 70% observation for Training Dataset.
# 30% observation for Test Dataset

# %%
X = df.iloc[:, 1:].values
y = df.iloc[:, 0].values

# %% [markdown]
# ### splitting data into X-train, X-test and Y-train, Y-test

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %% [markdown]
# ### making data balance using standerdization

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()

X_train[:, 0:2] = sc.fit_transform(X_train[:,0:2])
X_test[:, 0:2] = sc.transform(X_test[:,0:2])

# %%
X_train[:, 8:10] = sc.fit_transform(X_train[:,8:10])
X_test[:, 8:10] = sc.transform(X_test[:,8:10])

# %%
X_train[:,23:24] = sc.fit_transform(X_train[:,23:24])
X_test[:,23:24] = sc.transform(X_test[:,23:24])

# %% [markdown]
# # SMOTE (Synthetic Minority Oversampling Technique) – Oversampling
#
# SMOTE (synthetic minority oversampling technique) is one of the most commonly used oversampling methods to solve the imbalance problem.
# It aims to balance class distribution by randomly increasing minority class examples by replicating them.
# SMOTE synthesises new minority instances between existing minority instances. It generates the virtual training records by linear interpolation for the minority class. These synthetic training records are generated by randomly selecting one or more of the k-nearest neighbors for each example in the minority class. After the oversampling process, the data is reconstructed and several classification models can be applied for the processed data.

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 2)
X_train_res, y_train_res = sm.fit_resample(X_train, y_train)

# %%
print("Before OverSampling, counts of label '1': {}".format(sum(y_train == 1)))
print("Before OverSampling, counts of label '0': {} \n".format(sum(y_train == 0)))
# Out:
# Before OverSampling, counts of label '1': 167
# Before OverSampling, counts of label '0': 862

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state = 2)
X_train_res, y_train_res = sm.fit_sample(X_train, y_train)

# %%
print('After OverSampling, the shape of train_X: {}'.format(X_train_res.shape))
print('After OverSampling, the shape of train_y: {} \n'.format(y_train_res.shape))

print("After OverSampling, counts of label '1': {}".format(sum(y_train_res == 1)))
print("After OverSampling, counts of label '0': {}".format(sum(y_train_res == 0)))
# Out:
# After OverSampling, the shape of train_X: (1724, 43)
# After OverSampling, the shape of train_y: (1724,)
#
# After OverSampling, counts of label '1': 862
# After OverSampling, counts of label '0': 862

# %% [markdown]
# ## 1. Logistic Regression
# ### using smote

# %%
from sklearn.linear_model import LogisticRegression
clas = LogisticRegression(random_state = 0)
clas.fit(X_train_res, y_train_res)
# Out:
# c:\users\vikra\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=0)

# %%
# logistic regression object
lr = LogisticRegression()

# train the model on train set
lr.fit(X_train_res, y_train_res)

predictions = lr.predict(X_test)

#import classification report
from sklearn.metrics import confusion_matrix, classification_report

# print classification report
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89       371
#            1       0.40      0.40      0.40        70
#
#     accuracy                           0.81       441
#    macro avg       0.64      0.64      0.64       441
# weighted avg       0.81      0.81      0.81       441
# c:\users\vikra\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ### Confusion matrix

# %%
y_pred = clas.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
acc_org = accuracy_score(y_test, y_pred)
# Out:
# [[329  42]
#  [ 42  28]]

# %%
sns.heatmap(cm,annot=True)
plt.show()
print("accuracy=", acc_org )
# Out:
# accuracy= 0.8095238095238095

# %% [markdown]
# ### without smote

# %%
from sklearn.linear_model import LogisticRegression
LR_classifier = LogisticRegression(random_state = 0)
LR_classifier.fit(X_train, y_train)
# Out:
# c:\users\vikra\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=0)

# %%
y_pred = LR_classifier.predict(X_test)

# %% [markdown]
# ### confusion matrix

# %%
y_pred = LR_classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[366   5]
#  [ 43  27]]

# %%
sns.heatmap(cm,annot=True)
plt.show()

# %% [markdown]
# ### accuracy score without smote

# %%
from sklearn.metrics import accuracy_score
acc1 = accuracy_score(y_test, y_pred)
print(f"Accuracy score for Logistic Regression Model : {acc1}")
# Out:
# Accuracy score for Logistic Regression Model : 0.891156462585034

# %% [markdown]
# ### accuracy score using smote

# %%
from sklearn.model_selection import cross_val_score

accuracies = cross_val_score(estimator = LR_classifier, X = X_train_res, y = y_train_res, cv = 10)
print("Accuracy of Logistic Regression using Cross Validation : {:.2f} %".format(accuracies.mean()*100))
print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))
# Out:
# c:\users\vikra\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\vikra\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# ## Hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV

parameters = [{'penalty': ['l1','l2'], 'C': np.arange(1,10) }]

grid_search = GridSearchCV(estimator = LR_classifier,
                           param_grid = parameters,
                           scoring = 'accuracy',
                           cv = 10,
                           n_jobs = -1)

# %%
grid_search.fit(X_train_res, y_train_res)
LR_acc = grid_search.best_score_
best_parameters1 = grid_search.best_params_
# Out:
# c:\users\vikra\appdata\local\programs\python\python38\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 90 fits failed out of a total of 180.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 90 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\users\vikra\appdata\local\programs\python\python38\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\users\vikra\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py", line 1091, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
# ...

# %%
print("Accuracy score for Logestic Regression after Hyperparameter Tuning : {:.2f} %".format(LR_acc*100))
print("Best Parameters:", best_parameters1)
# Out:
# Accuracy score for Logestic Regression after Hyperparameter Tuning : 86.56 %
# Best Parameters: {'C': 6, 'penalty': 'l2'}

# %% [markdown]
# # 2. SVM
# ## with Smote

# %%
from sklearn.svm import SVC
classifier2 = SVC(kernel = 'linear', random_state = 0)
SVM_classifier = classifier2.fit(X_train_res, y_train_res)

# %% [markdown]
# ### confusion matrix

# %%
y_pred = SVM_classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[346  25]
#  [ 43  27]]

# %%
sns.heatmap(cm,annot=True)
plt.show()

# %%
acc2 = accuracy_score(y_test, y_pred)
print("Accuracy score for SVM Model: {:.2f} %".format(acc2*100))
# Out:
# Accuracy score for SVM Model: 84.58 %

# %%
from sklearn.model_selection import cross_val_score

accuracies = cross_val_score(estimator = SVM_classifier, X = X_train_res, y = y_train_res, cv = 10)
print("Accuracy of SVM Model in Cross Validation: {:.2f} %".format(accuracies.mean()*100))
print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))
# Out:
# Accuracy of SVM Model in Cross Validation: 87.78 %
# Standard Deviation: 11.51 %

# %% [markdown]
# ## hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV

parameters = [{'C': np.arange(1,10) }]

grid_search = GridSearchCV(estimator = SVM_classifier,
                           param_grid = parameters,
                           scoring = 'accuracy',
                           cv = 10,
                           n_jobs = -1)

# %%
grid_search.fit(X_train_res, y_train_res)
SVM_acc = grid_search.best_score_
best_parameters2 = grid_search.best_params_

# %%
print("Best Accuracy of SVM after Hyperparameter tuning: {:.2f} %".format(SVM_acc*100))
print("Best Parameters of SVM:", best_parameters2)
# Out:
# Best Accuracy of SVM after Hyperparameter tuning: 88.07 %
# Best Parameters of SVM: {'C': 3}

# %% [markdown]
# # 3. KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
KNN_classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
KNN_classifier.fit(X_train_res, y_train_res)
y_pred = KNN_classifier.predict(X_test)

# %% [markdown]
# ### confusion matrix

# %%
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[246 125]
#  [ 35  35]]

# %%
sns.heatmap(cm,annot=True)
plt.show()

# %%
acc3 = accuracy_score(y_test, y_pred)
print("Best Accuracy of K-NN: {:.2f} %".format(acc3*100))
# Out:
# Best Accuracy of K-NN: 63.72 %

# %%
from sklearn.model_selection import cross_val_score

accuracies = cross_val_score(estimator = KNN_classifier, X = X_train_res, y = y_train_res, cv = 10)
print("Accuracy of KNN in Cross Validation: {:.2f} %".format(accuracies.mean()*100))
print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))
# Out:
# Accuracy of KNN in Cross Validation: 80.63 %
# Standard Deviation: 2.34 %

# %% [markdown]
# ## hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV

parameters = [{ 'n_neighbors' :  np.arange(1,10)  }]

grid_search = GridSearchCV(estimator = KNN_classifier,
                           param_grid = parameters,
                           scoring = 'accuracy',
                           cv = 10,
                           n_jobs = -1)

# %%
grid_search.fit(X_train_res, y_train_res)
KNN_acc = grid_search.best_score_
best_parameters3 = grid_search.best_params_

# %%
print("Best Accuracy of KNN after Hyperparameter tuning: {:.2f} %".format(KNN_acc*100))
print("Best Parameters of KNN:", best_parameters3)
# Out:
# Best Accuracy of KNN after Hyperparameter tuning: 89.50 %
# Best Parameters of KNN: {'n_neighbors': 2}

# %% [markdown]
# # 4. Naive Baise

# %%
from sklearn.naive_bayes import GaussianNB
NB_classifier = GaussianNB()
NB_classifier.fit(X_train_res, y_train_res)
# Out:
# GaussianNB()

# %% [markdown]
# ### confusion matrix

# %%
y_pred = NB_classifier.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[225 146]
#  [ 29  41]]

# %%
sns.heatmap(cm,annot=True)
plt.show()

# %%
acc4 = accuracy_score(y_test, y_pred)
print(f"Accuracy score for Naive Bayes: {acc4}")
# Out:
# Accuracy score for Naive Bayes: 0.6031746031746031

# %%
from sklearn.model_selection import cross_val_score

NB_acc1 = cross_val_score(estimator = NB_classifier, X = X_train_res, y = y_train_res, cv = 10)
print("Accuracy of Naive Bayes in Cross Validation: {:.2f} %".format(NB_acc1.mean()*100))
print("Standard Deviation: {:.2f} %".format(NB_acc1.std()*100))
NB_acc = NB_acc1.mean()
# Out:
# Accuracy of Naive Bayes in Cross Validation: 74.26 %
# Standard Deviation: 7.12 %

# %% [markdown]
# # 5. Desision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

regressor = DecisionTreeRegressor(random_state = 0)
#fitting decision tree on data

regressor1 = regressor.fit(X_train_res,y_train_res)
# make predictions on the testing set
y_pred = regressor1.predict(X_test)

# %%
# import module to be used for model evaluation

from sklearn import metrics

# %%
# Mean Squared Error
print("Mean square error (MSE):", metrics.mean_squared_error(y_test,y_pred))
# Out:
# Mean square error (MSE): 0.2675736961451247

# %%
# Root Mean Squared Error
print("Root mean square error (RMSE):", np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# Root mean square error (RMSE): 0.5172752614857246

# %%
#cross-checking

df_check = pd.DataFrame({'Actual': y_test[:10], 'Predicted': y_pred[:10].ravel()})
df_check
# Out:
#    Actual  Predicted
# 0       0        0.0
# 1       0        0.0
# 2       1        0.0
# 3       0        1.0
# 4       1        1.0
# 5       0        1.0
# 6       1        0.0
# 7       0        1.0
# 8       0        0.0
# 9       1        1.0

# %% [markdown]
# ### confusion matrix

# %%
y_pred = regressor1.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[306  65]
#  [ 53  17]]

# %%
sns.heatmap(cm,annot=True)
plt.show()

# %%
DT_R_acc5 = accuracy_score(y_test, y_pred)
print("Accuracy score for Decision Tree : {:.2f} %".format(DT_R_acc5*100))
# Out:
# Accuracy score for Decision Tree : 73.24 %

# %% [markdown]
# ## hyper parameter tuning

# %%
from sklearn.tree import DecisionTreeClassifier
DT_classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
DT_classifier.fit(X_train_res, y_train_res)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
y_pred = DT_classifier.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[300  71]
#  [ 43  27]]

# %%
sns.heatmap(cm,annot=True)
plt.show()

# %%
from sklearn import metrics

# View summary of common classification metrics

print("---Metrices---")
print(metrics.classification_report(y_true = y_test, y_pred = y_pred))
# Out:
# ---Metrices---
#               precision    recall  f1-score   support
#
#            0       0.87      0.81      0.84       371
#            1       0.28      0.39      0.32        70
#
#     accuracy                           0.74       441
#    macro avg       0.58      0.60      0.58       441
# weighted avg       0.78      0.74      0.76       441

# %%
DT_C_acc5 = accuracy_score(y_test, y_pred)
print("Accuracy score for Decision Tree: {:.2f} %".format(DT_C_acc5*100))
# Out:
# Accuracy score for Decision Tree: 74.15 %

# %%
from sklearn.model_selection import cross_val_score

accuracies = cross_val_score(estimator = DT_classifier, X = X_train_res, y = y_train_res, cv = 10)
print("Accuracy of Decision Tree Classifier: {:.2f} %".format(accuracies.mean()*100))
print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))
# Out:
# Accuracy of Decision Tree Classifier: 83.08 %
# Standard Deviation: 8.29 %

# %% [markdown]
# ## hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV

parameters = [{  }]

grid_search = GridSearchCV(estimator = DT_classifier,
                           param_grid = parameters,
                           scoring = 'accuracy',
                           cv = 10,
                           n_jobs = -1)

# %%
grid_search.fit(X_train_res, y_train_res)
DT_acc = grid_search.best_score_
best_parameters5 = grid_search.best_params_

# %%
print("Best Accuracy of Decision Tree Classifier: {:.2f} %".format(DT_acc*100))
print("Best Parameters of Decision Tree Classifier:", best_parameters5)
# Out:
# Best Accuracy of Decision Tree Classifier: 83.08 %
# Best Parameters of Decision Tree Classifier: {}

# %% [markdown]
# # 6. Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
RF_classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
RF_classifier.fit(X_train_res, y_train_res)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %% [markdown]
# ### confusion matrix

# %%
y_pred = RF_classifier.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[355  16]
#  [ 55  15]]

# %%
sns.heatmap(cm,annot=True)
plt.show()

# %%
RF_acc6 = accuracy_score(y_test, y_pred)
print("Accuracy score for Random Forest: {:.2f} %".format(RF_acc6*100))
# Out:
# Accuracy score for Random Forest: 83.90 %

# %%
from sklearn.model_selection import cross_val_score

accuracies = cross_val_score(estimator = classifier2, X = X_train_res, y = y_train_res, cv = 10)
print("Accuracy of Random Forest in Cross Validation: {:.2f} %".format(accuracies.mean()*100))
print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))
# Out:
# Accuracy of Random Forest in Cross Validation: 87.78 %
# Standard Deviation: 11.51 %

# %% [markdown]
# ## hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV

parameters = [{'n_estimators' : [10, 50, 100, 200], 'max_depth' : [3, 10, 20, 40]}]

grid_search = GridSearchCV(estimator = RF_classifier,
                           param_grid = parameters,
                           scoring = 'accuracy',
                           cv = 10,
                           n_jobs = -1)

# %%
grid_search.fit(X_train_res, y_train_res)
RF_acc = grid_search.best_score_
best_parameters6 = grid_search.best_params_

# %%
print("Best Accuracy of Random Forest with hyperparameter tuning: {:.2f} %".format(RF_acc*100))
print("Best Parameters of Random Forest:", best_parameters6)
# Out:
# Best Accuracy of Random Forest with hyperparameter tuning: 92.01 %
# Best Parameters of Random Forest: {'max_depth': 20, 'n_estimators': 200}

# %%
mylist=[]
mylist2=[]
mylist.append(LR_acc)
mylist2.append("Logistic Regression")
mylist.append(SVM_acc)
mylist2.append("SVM")
mylist.append(KNN_acc)
mylist2.append("KNN")
mylist.append(NB_acc)
mylist2.append("Naive Bayes")
mylist.append(DT_acc)
mylist2.append("DTC")
mylist.append(RF_acc)
mylist2.append("RFC")

plt.rcParams['figure.figsize']=22,10
sns.set_style("darkgrid")
ax = sns.barplot(x=mylist2, y=mylist, palette = "coolwarm", saturation =1.5)
plt.xlabel("Classification Models", fontsize = 20 )
plt.ylabel("Accuracy", fontsize = 20)
plt.title("Accuracy of different Classification Models", fontsize = 20)
plt.xticks(fontsize = 11, horizontalalignment = 'center', rotation = 8)
plt.yticks(fontsize = 13)
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height:.2%}', (x + width/2, y + height*1.02), ha='center', fontsize = 'x-large')
plt.show()

# %% [markdown]
# # Conclusion
#
# by observing above plot i can conclude that the Random Forest is a best algoritham to analyse whether the employee will atrrit or not and the best hyper parameter for random forest is 'max_depth': 20, 'n_estimators': 200.
# Hence, the HR can focus on such aspects and understand from the viewpoint of the employees. Once that is followed, the project that is called Attrition project can be used as a Retention project. This can immensely help the organization.
#
# Secondly, the model needs to be tuned from time to time as and when new dataset is received. In case any new input variable is introduced, it is important that the information is retrieved for the employees who participated in the initial study.
